# %% [markdown]
# # SciSciNet Test

# %%
import pandas as pd

# %% [markdown]
# ## Papers

# %%
# %%time
SciNet_Papers = pd.read_csv(
    '../Thesis/SciSciNet/SciSciNet_Papers.tsv', sep='\t')
SciNet_Papers

# %% [markdown]
# ## Journals

# %%
# %%time
SciNet_Journals = pd.read_csv(
    '../Thesis/SciSciNet/SciSciNet_Journals.tsv', sep='\t')
SciNet_Journals
# Out:
# CPU times: user 58.9 ms, sys: 14.5 ms, total: 73.4 ms
# Wall time: 82.8 ms
#         JournalID                                       Journal_Name  \
# 0          465895                                             Eureka
# 1         1137746             The Artist and Journal of Home Culture
# 2         2978343                              Cumberland Law Review
# 3         3010151                 Comparative Medicine East and West
# 4         3164724                          Physiological Measurement
# ...           ...                                                ...
# 49061  2765076455  Journal of Changsha University of Science & Te...
# 49062  2898398052                                 Reviews in Physics
# 49063  2898614270              Revista de Psiquiatría y Salud Mental
# 49064  2933375274                   Indonesian Journal of Cardiology
# 49065  3012825557  International Journal of Occupational and Envi...
#
#             ISSN                     Publisher  \
# ...

# %% [markdown]
# ## Affiliations

# %%
# %%time
SciNet_Affiliations = pd.read_csv(
    '../Thesis/SciSciNet/SciSciNet_Affiliations.tsv', sep='\t')
SciNet_Affiliations
# Out:
# CPU times: user 66.2 ms, sys: 11.3 ms, total: 77.5 ms
# Wall time: 76.3 ms
#        AffiliationID                                   Affiliation_Name  \
# 0           20455151                                        Air Liquide
# 1           24386293           Hellenic National Meteorological Service
# 2           32956416                    Catholic University of the West
# 3           35926432                             Mackay Medical College
# 4           37448385        Chinese People's Public Security University
# ...              ...                                                ...
# 26993     3130807960                 Diamond Harbour Women's University
# 26994     3131031036                   Mediterranean School of Business
# 26995     3132176766    Torbat Heydarieh University of Medical Sciences
# 26996     3132554608  University of the Latin American Educational C...
# 26997     3132999081                                 Marwadi University
#
# ...

# %% [markdown]
# ## Authours

# %%
# %%time
SciNet_Author = pd.read_csv(
    '../Thesis/SciSciNet/SciSciNet_Authors.tsv', sep='\t')
SciNet_Author
# Out:
# CPU times: user 56.6 s, sys: 22.3 s, total: 1min 18s
# Wall time: 2min 48s
#              AuthorID                Author_Name  H-index  Productivity  \
# 0                 584     Gözde Özdikmenli-Demir        3             5
# 1                 859                 Gy. Tolmár        1             3
# 2                 978             Ximena Faúndez        4            10
# 3                1139             Jennifer Putzi        1             4
# 4                1476                      勲矢 手島        0             1
# ...               ...                        ...      ...           ...
# 134197157  3217810999              Junghwa Hwang        0             1
# 134197158  3217811001       فرحان العتيبي، أفراح        0             1
# 134197159  3217811010                      Rongo        1             1
# 134197160  3217811011                 Zhen Zhang        0             1
# 134197161  3217811013  Mu’amar Musa Nurwigantara        0             1
#
# ...

# %% [markdown]
# ## Paper Authour Affiliations

# %%
# %%time
SciNet_PaperAuthorAffiliations = pd.read_csv(
    '../Thesis/SciSciNet/SciSciNet_PaperAuthorAffiliations.tsv', sep='\t')
SciNet_PaperAuthorAffiliations

# %% [markdown]
# ## Fields

# %% [markdown]
# ## Paper Fields

# %%
# %%time
SciNet_PaperFields = pd.read_csv(
    '../Thesis/SciSciNet/SciSciNet_PaperFields.tsv', sep='\t')
SciNet_PaperFields
# Out:
# CPU times: user 48.7 s, sys: 10.9 s, total: 59.6 s
# Wall time: 1min 16s
#               PaperID    FieldID  Hit_1pct  Hit_5pct  Hit_10pct       C_f
# 0            18936224   71924100       0.0       0.0        0.0  0.731404
# 1            94748468  144024400       0.0       0.0        0.0  0.000000
# 2           113998959   71924100       0.0       0.0        0.0  0.270789
# 3            56740461  144133560       0.0       0.0        0.0  0.328162
# 4                  23   71924100       0.0       0.0        0.0  0.169123
# ...               ...        ...       ...       ...        ...       ...
# 277494989  3204507150  188027245       0.0       0.0        0.0  0.000000
# 277494990  3204507160  187212893       0.0       0.0        0.0  0.000000
# 277494991  3204507164  143998085       0.0       0.0        0.0  0.000000
# 277494992  3204507164  126322002       0.0       0.0        0.0  0.000000
# 277494993  3204507171   34447519       0.0       0.0        0.0  0.000000
#
# ...

# %%
Physics_FieldId=SciNet_PaperFields[SciNet_PaperFields['FieldID']==121332964]
Physics_FieldId
# Out:
#               PaperID    FieldID  Hit_1pct  Hit_5pct  Hit_10pct       C_f
# 13           38064030  121332964       0.0       0.0        0.0  0.093360
# 29          132789625  121332964       0.0       0.0        0.0  0.108901
# 61          170361713  121332964       0.0       0.0        0.0  0.000000
# 62           56740737  121332964       0.0       0.0        0.0  1.038744
# 98          208270992  121332964       0.0       0.0        0.0  0.347295
# ...               ...        ...       ...       ...        ...       ...
# 116942077  3204506570  121332964       0.0       0.0        0.0  0.000000
# 116942079  3204506608  121332964       0.0       0.0        0.0  0.000000
# 116942082  3204506667  121332964       0.0       0.0        0.0  0.000000
# 116942111  3204506902  121332964       0.0       0.0        0.0  0.000000
# 116942133  3204507122  121332964       0.0       0.0        0.0  0.000000
#
# [5153365 rows x 6 columns]

# %% [markdown]
# ## Paper References

# %% [markdown]
# ## Nobel laureates

# %% [markdown]
# ## Gender

# %%
# %%time
SciNet_AuthorsGender = pd.read_csv(
    '../Thesis/SciSciNet/SciSciNet_Authors_Gender.tsv', sep='\t')
SciNet_AuthorsGender
